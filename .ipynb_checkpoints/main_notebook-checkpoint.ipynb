# %% [markdown]
# # Use this notbook for your 3 choices of APIs

# %%
# Working-With-APIs
# In this lab you will choose 3 APIs from the list in the GitHub Repo
# Create a dataframe of the available data and think of a project that you could do with that data.
# Submit your notebook's repo link in the Student Portal.

# %%
# Oslo university code, course name and url finder

# %%
import pandas as pd
import requests

res = requests.get('https://data.uio.no/studies/v1/courses')

# %%
type(res)
# Out:
# requests.models.Response

# %%
data = res.json()
data
# looks like a list of dictionaries
#
# Out:
# {'courses': [{'code': '4360',
#    'name': 'Macroeconomic policy and models',
#    'url': 'https://www.uio.no/studier/emner/sv/oekonomi/ECON4360/index.html'},
#   {'code': '4410',
#    'name': 'Introductory dynamic macroeconomics',
#    'url': 'https://www.uio.no/studier/emner/sv/oekonomi/ECON4410/index.html'},
#   {'code': '4940',
#    'name': 'Economic Reform in China',
#    'url': 'https://www.uio.no/studier/emner/sv/oekonomi/ECON4940/index.html'},
#   {'code': '5210',
#    'name': 'Topics in microeconomics',
#    'url': 'https://www.uio.no/studier/emner/sv/oekonomi/ECON5210/index.html'},
#   {'code': '5315',
#    'name': 'Recursive Macroeconomic Theory',
#    'url': 'https://www.uio.no/studier/emner/sv/oekonomi/ECON5315/index.html'},
#   {'code': 'AAS4900',
#    'name': 'Internasjonalt prosjektsemester Asia og Afrika',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/AAS4900/index.html'},
#   {'code': 'AMS4900',
#    'name': 'Internasjonalt prosjektsemester Asia og Midtøsten',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/AMS4900/index-eng.html'},
#   {'code': 'ANMAT5930',
#    'name': 'Masteroppgave i anvendt matematikk og mekanikk 30 studiepoeng',
#    'url': 'https://www.uio.no/studier/emner/matnat/math/ANMAT5930/index.html'},
#   {'code': 'ANMAT5960',
#    'name': 'Masteroppgave i anvendt matematikk og mekanikk 60 studiepoeng',
#    'url': 'https://www.uio.no/studier/emner/matnat/math/ANMAT5960/index.html'},
#   {'code': 'ANT1001V',
#    'name': 'Antikkens kultur',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT1001V/index.html'},
#   {'code': 'ANT1100',
#    'name': 'Antikkens verden',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT1100/index.html'},
#   {'code': 'ANT1101',
#    'name': 'Introduksjon til klassisk filologi for kultur- og historiestudenter',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT1101/index.html'},
#   {'code': 'ANT1500',
#    'name': 'Antikken gjennom tidene',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT1500/index.html'},
#   {'code': 'ANT1501',
#    'name': 'Antikkresepsjon',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT1501/index.html'},
#   {'code': 'ANT2210',
#    'name': 'Antikkens Roma',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT2210/index.html'},
#   {'code': 'ANT2211',
#    'name': 'Antikkens Roma - påbygning',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT2211/index.html'},
#   {'code': 'ANT2220',
#    'name': 'Den klassiske kulturen – Athen i klassisk tid (500-300 f.Kr)',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT2220/index.html'},
#   {'code': 'ANT2221',
#    'name': 'Athen i klassisk tid - påbygning',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT2221/index.html'},
#   {'code': 'ANT2222',
#    'name': 'Athen i klassisk tid',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT2222/index.html'},
#   {'code': 'ANT2700',
#    'name': 'Antikkens litteratur i oversettelse ',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT2700/index.html'},
#   {'code': 'ANT2800',
#    'name': 'Antikkens mytologi',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT2800/index.html'},
#   {'code': 'ANT3090',
#    'name': 'Antikk kultur: bacheloroppgave',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT3090/index.html'},
#   {'code': 'ANT4301',
#    'name': 'Moderne litteraturteorier og antikke tekster',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT4301/index.html'},
#   {'code': 'ANT4302',
#    'name': 'Ancient Theories of Literature',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT4302/index.html'},
#   {'code': 'ANT4500',
#    'name': 'Antikkens rolle i europeiske ideologier: nærlesning av sentrale tekster fra den klassiske tradisjonen',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT4500/index.html'},
#   {'code': 'ANT4501',
#    'name': 'Ancient Heritages: Premodern Perspectives',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT4501/index.html'},
#   {'code': 'ANT4502',
#    'name': 'Prosjektutvikling og introduksjon til antikkforskning',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT4502/index.html'},
#   {'code': 'ANT4510',
#    'name': 'Theory and History of Classical Philology',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT4510/index.html'},
#   {'code': 'ANT4600',
#    'name': 'Digital methods in classical philology',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT4600/index.html'},
#   {'code': 'ANT4700',
#    'name': 'Antikkens litteratur i oversettelse ',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT4700/index.html'},
#   {'code': 'ANT4900',
#    'name': 'Praksisemne for masterprogrammet i klassiske språk',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/ANT4900/index.html'},
#   {'code': 'ANTH4010',
#    'name': 'Advanced Anthropological Theory',
#    'url': 'https://www.uio.no/studier/emner/sv/sai/ANTH4010/index.html'},
#   {'code': 'ANTH4020',
#    'name': 'Academic Writing and Project Development',
#    'url': 'https://www.uio.no/studier/emner/sv/sai/ANTH4020/index.html'},
#   {'code': 'ANTH4030',
#    'name': 'Advanced Anthropological Methods',
#    'url': 'https://www.uio.no/studier/emner/sv/sai/ANTH4030/index.html'},
#   {'code': 'ANTH4090',
#    'name': 'Master thesis',
#    'url': 'https://www.uio.no/studier/emner/sv/sai/ANTH4090/index.html'},
#   {'code': 'ANTH4100',
#    'name': 'Core Themes in Contemporary Anthropology',
#    'url': 'https://www.uio.no/studier/emner/sv/sai/ANTH4100/index.html'},
#   {'code': 'ANTH4150',
#    'name': 'Ethnography in Practice',
#    'url': 'https://www.uio.no/studier/emner/sv/sai/ANTH4150/index.html'},
#   {'code': 'ANTH4200',
#    'name': 'Fieldwork',
#    'url': 'https://www.uio.no/studier/emner/sv/sai/ANTH4200/index.html'},
#   {'code': 'ANTH4610',
#    'name': 'Work, Capital and Business',
#    'url': 'https://www.uio.no/studier/emner/sv/sai/ANTH4610/index.html'},
#   {'code': 'ANTH4620',
#    'name': 'Finance, Markets and Resources',
#    'url': 'https://www.uio.no/studier/emner/sv/sai/ANTH4620/index.html'},
#   {'code': 'ANTH4710',
#    'name': 'Internship',
#    'url': 'https://www.uio.no/studier/emner/sv/sai/ANTH4710/index.html'},
#   {'code': 'ANTH4720',
#    'name': 'Searching ethnographic form: About the boundaries of writing about the boundaries of our world',
#    'url': 'https://www.uio.no/studier/emner/sv/sai/ANTH4720/index.html'},
#   {'code': 'ANTH4730',
#    'name': 'Critical Readings in Visual Anthropology: Ethnography, Theory, and Experimentation',
#    'url': 'https://www.uio.no/studier/emner/sv/sai/ANTH4730/index.html'},
#   {'code': 'ARA1010',
#    'name': 'Arabisk A',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA1010/index.html'},
#   {'code': 'ARA1020',
#    'name': 'Arabisk B',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA1020/index.html'},
#   {'code': 'ARA1030',
#    'name': 'Arabisk C',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA1030/index.html'},
#   {'code': 'ARA1110',
#    'name': 'Arabisk språk 1',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA1110/index.html'},
#   {'code': 'ARA1120',
#    'name': 'Arabisk språk 2',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA1120/index.html'},
#   {'code': 'ARA1121',
#    'name': 'Innføring i arabisk språkhistorie, språkforhold og dialektologi',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA1121/index.html'},
#   {'code': 'ARA2010',
#    'name': 'Arabisk D',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA2010/index.html'},
#   {'code': 'ARA2011',
#    'name': 'Arabisk D del 1',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ara2011/index.html'},
#   {'code': 'ARA2012',
#    'name': 'Arabisk D del 2',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ara2012/index.html'},
#   {'code': 'ARA2110',
#    'name': 'Arabisk språk 3+4',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA2110/index.html'},
#   {'code': 'ARA2121',
#    'name': 'Innføring i arabisk språkhistorie, språkforhold og dialektologi',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA2121/index.html'},
#   {'code': 'ARA2130',
#    'name': 'Fordypningsemne i arabisk',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA2130/index.html'},
#   {'code': 'ARA3010',
#    'name': 'Arabisk E',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA3010/index.html'},
#   {'code': 'ARA3110',
#    'name': 'Arabisk språk 5',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA3110/index.html'},
#   {'code': 'ARA3120',
#    'name': 'Arabisk språk 6',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA3120/index.html'},
#   {'code': 'ARA4110',
#    'name': 'Emner fra arabisk språkhistorie, språkforhold og dialektologi',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA4110/index.html'},
#   {'code': 'ARA4111',
#    'name': '’Diglossi’ og språklig variasjon i moderne arabisk',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA4111/index.html'},
#   {'code': 'ARA4114',
#    'name': 'Arabic Linguistics',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA4114/index.html'},
#   {'code': 'ARA4115',
#    'name': 'Arabisk oversettelse',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA4115/index.html'},
#   {'code': 'ARA4116',
#    'name': 'Klassisk arabisk litteratur: grammatiske og kulturelle spørsmål',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA4116/index.html'},
#   {'code': 'ARA4117',
#    'name': 'Arabiske vitenskapelige tekster',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA4117/index.html'},
#   {'code': 'ARA4118',
#    'name': 'Arabic Manuscripts',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA4118/index.html'},
#   {'code': 'ARA4302',
#    'name': 'Readings in Arabic Literature, Religions and Politics',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA4302/index.html'},
#   {'code': 'ARA4303',
#    'name': 'Modern Arabic Fiction and Dramatic Arts',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA4303/index.html'},
#   {'code': 'ARA4304',
#    'name': 'Contemporary Arabic Literature: Texts and Contexts',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA4304/index.html'},
#   {'code': 'ARA4505',
#    'name': 'Arabic Cyberspace',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA4505/index.html'},
#   {'code': 'ARA4506',
#    'name': 'Key Concepts of Arabic Language and Culture – A Comparative Analysis',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA4506/index.html'},
#   {'code': 'ARA4590',
#    'name': 'Masteroppgave i arabisk',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA4590/index.html'},
#   {'code': 'ARA4592',
#    'name': 'Masteroppgave i arabisk',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARA4592/index.html'},
#   {'code': 'ARAM2110',
#    'name': 'Bibelhebraisk/Arameisk',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARAM2110/index.html'},
#   {'code': 'ARB1401',
#    'name': 'Design, kreativitet og innovasjon',
#    'url': 'https://www.uio.no/studier/emner/hf/imk/ARB1401/index.html'},
#   {'code': 'ARB1402',
#    'name': 'Kultur- og kunnskapsbransjer: Forretningsmodeller og økonomiforståelse',
#    'url': 'https://www.uio.no/studier/emner/hf/imk/ARB1402/index.html'},
#   {'code': 'ARB1403',
#    'name': 'Prosjektarbeid, kunnskapsdeling og digitale verktøy',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARB1403/index.html'},
#   {'code': 'ARB1404',
#    'name': 'Formidling og dialog i arbeidslivet',
#    'url': 'https://www.uio.no/studier/emner/hf/iln/ARB1404/index.html'},
#   {'code': 'ARK1000',
#    'name': 'Innføring i arkeologi',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK1000/index.html'},
#   {'code': 'ARK1010',
#    'name': 'Europeisk forhistorie fra paleolitikum til bronsealder',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK1010/index.html'},
#   {'code': 'ARK1020',
#    'name': 'Klassisk arkeologi-Middelhavsarkeologi',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK1020/index.html'},
#   {'code': 'ARK1030',
#    'name': 'Jernalder- og middelalderarkeologi i Nord-Europa med vekt på Norden',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK1030/index.html'},
#   {'code': 'ARK2000',
#    'name': 'Arkeologisk teori og faghistorie',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2000/index.html'},
#   {'code': 'ARK2010',
#    'name': 'Forhistorisk arkeologi - erstattes av ARK2050 f.o.m. høst 08',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2010/index.html'},
#   {'code': 'ARK2011',
#    'name': 'Forhistorisk arkeologi',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2011/index.html'},
#   {'code': 'ARK2020',
#    'name': 'Klassisk arkeologi - erstattes av ARK2050 f.o.m. høst 08',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2020/index.html'},
#   {'code': 'ARK2021',
#    'name': 'Classical Archaeology',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2021/index.html'},
#   {'code': 'ARK2030',
#    'name': 'Historisk arkeologi - erstattes av ARK2050 f.o.m. høst 08',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2030/index.html'},
#   {'code': 'ARK2031',
#    'name': 'Historisk arkeologi',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2031/index.html'},
#   {'code': 'ARK2040',
#    'name': 'Kjønn og arkeologi',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2040/index.html'},
#   {'code': 'ARK2050',
#    'name': 'Fordypning i kulturhistorisk arkeologi',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2050/index.html'},
#   {'code': 'ARK2051',
#    'name': 'Fordypning i kulturhistorisk arkeologi',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2051/index.html'},
#   {'code': 'ARK2080',
#    'name': 'Arkeologi, kropp og kjønn',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2080/index.html'},
#   {'code': 'ARK2110',
#    'name': 'Arkeologisk kulturminneforvaltning',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2110/index.html'},
#   {'code': 'ARK2120',
#    'name': 'Hunters, Gatherers, early Farmers and Stone age Technology',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2120/index.html'},
#   {'code': 'ARK2130',
#    'name': 'From the Bronze Age to the Vikings and Beyond. Archaeological Analysis of Past Technology',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2130/index.html'},
#   {'code': 'ARK2140',
#    'name': 'The Archaeology of Migration and Mobility',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2140/index.html'},
#   {'code': 'ARK2410',
#    'name': 'University of Oslo Summer School in Archaeology',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK2410/index.html'},
#   {'code': 'ARK3011',
#    'name': 'Fordypning i forhistorisk arkeologi (BA-avhandling)',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK3011/index.html'},
#   {'code': 'ARK3021',
#    'name': 'Fordypning i klassisk arkeologi (BA-avhandling)',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK3021/index.html'},
#   {'code': 'ARK3031',
#    'name': 'Fordypning i historisk arkeologi (BA-avhandling)',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK3031/index.html'},
#   {'code': 'ARK3090',
#    'name': 'Bacheloroppgave i arkeologi',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK3090/index.html'},
#   {'code': 'ARK4010',
#    'name': 'Seminar for muntlig fremlegging',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4010/index.html'},
#   {'code': 'ARK4020',
#    'name': 'Problemstillinger innen middelhavsarkeologi',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4020/index.html'},
#   {'code': 'ARK4040',
#    'name': 'Fordypning i arkeologisk teori og metode',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4040/index.html'},
#   {'code': 'ARK4041',
#    'name': 'Kjønn og arkeologi',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4041/index.html'},
#   {'code': 'ARK4050',
#    'name': 'Arkeologi og formidling',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4050/index.html'},
#   {'code': 'ARK4070',
#    'name': 'Environmental Archaeology and Archaeometry',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4070/index.html'},
#   {'code': 'ARK4080',
#    'name': 'Arkeologi, kropp og kjønn',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4080/index.html'},
#   {'code': 'ARK4090',
#    'name': 'Masteroppgave i arkeologi',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4090/index.html'},
#   {'code': 'ARK4100',
#    'name': 'Arkeologisk feltkurs og databehandling',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4100/index.html'},
#   {'code': 'ARK4110',
#    'name': 'Arkeologisk kulturminneforvaltning',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4110/index.html'},
#   {'code': 'ARK4120',
#    'name': 'Hunters, Gatherers, early Farmers and Stone Age Technology',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4120/index.html'},
#   {'code': 'ARK4130',
#    'name': 'From the Bronze Age to the Vikings and Beyond. Archaeological Analysis of Past Technology',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4130/index.html'},
#   {'code': 'ARK4140',
#    'name': 'The Archaeology of Migration and Mobility',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4140/index.html'},
#   {'code': 'ARK4150',
#    'name': 'Cape Field School Programme - South Africa',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4150/index.html'},
#   {'code': 'ARK4160',
#    'name': 'Lithic Technology',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4160/index.html'},
#   {'code': 'ARK4180',
#    'name': 'Arkeologisk praksis',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4180/index.html'},
#   {'code': 'ARK4200',
#    'name': 'Prosjektbeskrivelsesseminar',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4200/index.html'},
#   {'code': 'ARK4210',
#    'name': 'Kulturarvsarkeologi: om fortid i samtid',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4210/index.html'},
#   {'code': 'ARK4250',
#    'name': 'Prosjektbeskrivelse i arkeologi',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4250/index.html'},
#   {'code': 'ARK4300',
#    'name': 'Arkeologisk databehandling',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4300/index.html'},
#   {'code': 'ARK4310',
#    'name': 'Arkeologisk feltkurs, nordisk',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4310/index.html'},
#   {'code': 'ARK4410',
#    'name': 'University of Oslo Summer School in Archaeology',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/ARK4410/index.html'},
#   {'code': 'ARKIV1010',
#    'name': 'Arkivteori',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARKIV1010/index.html'},
#   {'code': 'ARKIV1020',
#    'name': 'Arkivdanning: organisasjon, systemer og rutiner',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARKIV1020/index.html'},
#   {'code': 'ARKIV1030',
#    'name': 'Arkiv, individ og samfunn',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARKIV1030/index.html'},
#   {'code': 'ARKIV1050',
#    'name': 'Arkivbevaring og arkivbeskrivelse',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARKIV1050/index.html'},
#   {'code': 'ARKIV2010',
#    'name': 'Arkivforvaltning i praksis',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARKIV2010/index.html'},
#   {'code': 'ARKIV2020',
#    'name': 'Dokumenthåndtering og elektronisk arkiv',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARKIV2020/index.html'},
#   {'code': 'ARKIV2030',
#    'name': 'Elektronisk arkiv',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARKIV2030/index.html'},
#   {'code': 'ARKIV2040',
#    'name': 'Arkivdanning i praksis',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARKIV2040/index.html'},
#   {'code': 'ARKIV2060',
#    'name': 'Depotfunksjoner i praksis',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ARKIV2060/index.html'},
#   {'code': 'AST1010',
#    'name': 'Astronomi - en kosmisk reise',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST1010/index.html'},
#   {'code': 'AST2000',
#    'name': 'Innføring i astrofysikk',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST2000/index.html'},
#   {'code': 'AST2210',
#    'name': 'Observasjonsastronomi',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST2210/index.html'},
#   {'code': 'AST3220',
#    'name': 'Kosmologi I',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST3220/index.html'},
#   {'code': 'AST3310',
#    'name': 'Astrofysiske plasma og stjernenes indre',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST3310/index.html'},
#   {'code': 'AST4310',
#    'name': 'Strålingsprosesser i astrofysikk',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST4310/index.html'},
#   {'code': 'AST4320',
#    'name': 'Kosmologi og ekstragalaktisk astronomi',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST4320/index.html'},
#   {'code': 'AST5110',
#    'name': 'Numerisk modellering',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST5110/index.html'},
#   {'code': 'AST5210',
#    'name': 'Stjerneatmosfærer I',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST5210/index.html'},
#   {'code': 'AST5220',
#    'name': 'Kosmologi II',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST5220/index.html'},
#   {'code': 'AST5240',
#    'name': 'Kosmologisk komponentseparering',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST5240/index.html'},
#   {'code': 'AST5770',
#    'name': 'Sol- og stjernefysikk',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST5770/index.html'},
#   {'code': 'AST9110',
#    'name': 'Numerisk modellering',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST9110/index.html'},
#   {'code': 'AST9240',
#    'name': 'Kosmologisk komponentseparering',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST9240/index.html'},
#   {'code': 'AST9310',
#    'name': 'Stjerneatmosfærer II',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST9310/index.html'},
#   {'code': 'AST9420',
#    'name': 'Kosmologi II',
#    'url': 'https://www.uio.no/studier/emner/matnat/astro/AST9420/index.html'},
#   {'code': 'B-LAB2000',
#    'name': 'Bærekraftlaboratoriet: tverrfaglig praksisemne',
#    'url': 'https://www.uio.no/studier/emner/hf/iakh/B-LAB2000/index.html'},
#   {'code': 'BAL1500',
#    'name': 'Balkan: Historie, kultur og samfunn',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BAL1500/index.html'},
#   {'code': 'BAL1501',
#    'name': 'Sørøst-Balkan: Historie, samfunn, kultur',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BAL1501/index.html'},
#   {'code': 'BAL3010',
#    'name': 'Balkan-linje, oppgaveemne',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BAL3010/index.html'},
#   {'code': 'BAL4550',
#    'name': 'Teori og metode for Balkan-studier',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BAL4550/index.html'},
#   {'code': 'BIO4320',
#    'name': 'Marine algers systematikk og økologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIO4320/index.html'},
#   {'code': 'BIO4325',
#    'name': 'Identification of Marine Microalgae and Macroalgae',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIO4325/index.html'},
#   {'code': 'BIO4371',
#    'name': 'Fiskeøkologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIO4371/index.html'},
#   {'code': 'BIO4400',
#    'name': 'Pelagisk økologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIO4400/index.html'},
#   {'code': 'BIO4600',
#    'name': 'Vitenskapelig forfatterskap',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIO4600/index.html'},
#   {'code': 'BIO5930L',
#    'name': 'Masteroppgave i biologi, Lektorprogrammet',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIO5930L/index.html'},
#   {'code': 'BIO9600',
#    'name': 'Vitenskapelig forfatterskap',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIO9600/index.html'},
#   {'code': 'BIO9905MERG1',
#    'name': 'Bioinformatics for Environmental Sequencing (DNA metabarcoding)',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIO9905MERG1/index.html'},
#   {'code': 'BIOS-IN5010',
#    'name': 'Computational physiology',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS-IN5010/index.html'},
#   {'code': 'BIOS-IN5410',
#    'name': 'Bioinformatics for Molecular Biology',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS-IN5410/index.html'},
#   {'code': 'BIOS-IN9010',
#    'name': 'Computational physiology',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS-IN9010/index.html'},
#   {'code': 'BIOS-IN9410',
#    'name': 'Bioinformatics for Molecular Biology',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS-IN9410/index.html'},
#   {'code': 'BIOS0100V',
#    'name': 'Grunnleggende biologi i naturfag',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS0100V/index.html'},
#   {'code': 'BIOS1100',
#    'name': 'Innføring i beregningsmodeller for biovitenskap',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS1100/index.html'},
#   {'code': 'BIOS1110',
#    'name': 'Celle- og molekylærbiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS1110/index.html'},
#   {'code': 'BIOS1120',
#    'name': 'Fysiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS1120/index.html'},
#   {'code': 'BIOS1130',
#    'name': 'Biokjemi I',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS1130/index.html'},
#   {'code': 'BIOS1140',
#    'name': 'Evolusjon og genetikk',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS1140/index.html'},
#   {'code': 'BIOS1150',
#    'name': 'Biologisk mangfold',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS1150/index.html'},
#   {'code': 'BIOS2000',
#    'name': 'Adferdsbiologi 1',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS2000/index.html'},
#   {'code': 'BIOS2100',
#    'name': 'Generell økologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS2100/index.html'},
#   {'code': 'BIOS2200',
#    'name': 'Botanisk mangfold',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS2200/index.html'},
#   {'code': 'BIOS2210',
#    'name': 'Terrestrisk zoologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS2210/index.html'},
#   {'code': 'BIOS2220',
#    'name': 'Akvatisk biomangfold',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS2220/index.html'},
#   {'code': 'BIOS2900',
#    'name': 'Molekylærbiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS2900/index.html'},
#   {'code': 'BIOS2910',
#    'name': 'Molekylærbiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS2910/index.html'},
#   {'code': 'BIOS3000',
#    'name': 'Design and analysis of biological studies',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS3000/index.html'},
#   {'code': 'BIOS3010',
#    'name': 'Bioinformatikk',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS3010/index.html'},
#   {'code': 'BIOS3050',
#    'name': 'Arbeidspraksis i biovitenskap',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS3050/index.html'},
#   {'code': 'BIOS3060',
#    'name': 'Forskningspraksis i biovitenskap',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS3060/index.html'},
#   {'code': 'BIOS3100',
#    'name': 'Evolusjon',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS3100/index.html'},
#   {'code': 'BIOS3250',
#    'name': 'Soppenes biologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS3250/index.html'},
#   {'code': 'BIOS3300',
#    'name': 'Marinbiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS3300/index.html'},
#   {'code': 'BIOS3600',
#    'name': 'Genetikk og utviklingsbiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS3600/index.html'},
#   {'code': 'BIOS3601',
#    'name': 'Genetikk og utviklingsbiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS3601/index.html'},
#   {'code': 'BIOS3610',
#    'name': 'Plantevitenskap',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS3610/index.html'},
#   {'code': 'BIOS3700',
#    'name': 'Cellebiologi 2',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS3700/index.html'},
#   {'code': 'BIOS3800',
#    'name': 'Humanfysiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS3800/index.html'},
#   {'code': 'BIOS3900',
#    'name': 'Biokjemi 2',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS3900/index.html'},
#   {'code': 'BIOS3910',
#    'name': 'Mikrobiologi og mykologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS3910/index.html'},
#   {'code': 'BIOS3920',
#    'name': 'Forskningslitteratur i kreftbiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS3920/index.html'},
#   {'code': 'BIOS4000',
#    'name': 'Design og analyse av biologiske studier',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4000/index.html'},
#   {'code': 'BIOS4010',
#    'name': 'Arbeidsmetoder i molekylærbiologi og biokjemi I',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4010/index.html'},
#   {'code': 'BIOS4020',
#    'name': 'Arbeidsmetoder i molekylærbiologi og biokjemi II',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4020/index.html'},
#   {'code': 'BIOS4030',
#    'name': 'Cellebiologiske arbeidsmetoder',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4030/index.html'},
#   {'code': 'BIOS4070',
#    'name': 'Biogeokjemi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4070/index.html'},
#   {'code': 'BIOS4100',
#    'name': 'Evolusjon',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4100/index.html'},
#   {'code': 'BIOS4120',
#    'name': 'Norsk naturvariasjon - typeinndeling, beskrivelse og kartlegging av natur basert på Natur i Norge (NiN)',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4120/index.html'},
#   {'code': 'BIOS4215',
#    'name': 'Evolusjon og systematikk i utvalgte grupper: dyreriket',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4215/index.html'},
#   {'code': 'BIOS4216',
#    'name': 'Evolusjon og systematikk i utvalgte grupper: planteriket',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4216/index.html'},
#   {'code': 'BIOS4218',
#    'name': 'Feltkurs i tropisk regnskogsøkologi og biomangfold',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4218/index.html'},
#   {'code': 'BIOS4250',
#    'name': 'Soppenes biologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4250/index.html'},
#   {'code': 'BIOS4300',
#    'name': 'Marinbiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4300/index.html'},
#   {'code': 'BIOS4301',
#    'name': 'Marin bentisk økologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4301/index.html'},
#   {'code': 'BIOS4315',
#    'name': 'Fiskeøkologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4315/index.html'},
#   {'code': 'BIOS4400',
#    'name': 'Pelagisk økologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4400/index.html'},
#   {'code': 'BIOS4500',
#    'name': 'Generell toksikologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4500/index.html'},
#   {'code': 'BIOS4600',
#    'name': 'Genetikk og utviklingsbiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4600/index.html'},
#   {'code': 'BIOS4601',
#    'name': 'Genetikk og utviklingsbiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4601/index.html'},
#   {'code': 'BIOS4610',
#    'name': 'Plantevitenskap',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4610/index.html'},
#   {'code': 'BIOS4910IGEM',
#    'name': 'International Genetically Engineered Machine',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS4910IGEM/index.html'},
#   {'code': 'BIOS5000',
#    'name': 'Biologididaktikk i praksis',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5000/index.html'},
#   {'code': 'BIOS5111',
#    'name': 'Elektronmikroskopi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5111/index.html'},
#   {'code': 'BIOS5112',
#    'name': 'Life-history strategies and climate effects',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5112/index.html'},
#   {'code': 'BIOS5113',
#    'name': 'Bevarings- og forvaltningsbiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5113/index.html'},
#   {'code': 'BIOS5114',
#    'name': 'Molekylær evolusjon',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5114/index.html'},
#   {'code': 'BIOS5210',
#    'name': 'Gradientanalyseteknikker',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5210/index.html'},
#   {'code': 'BIOS5211',
#    'name': 'Utbredelsesmodellering',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5211/index.html'},
#   {'code': 'BIOS5213',
#    'name': 'Fylogeni og klassifikasjon',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5213/index.html'},
#   {'code': 'BIOS5214',
#    'name': 'Biogeografi og biodiversitet',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5214/index.html'},
#   {'code': 'BIOS5217',
#    'name': 'Evolusjon og systematikk i utvalgte grupper: soppriket',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5217/index.html'},
#   {'code': 'BIOS5219',
#    'name': 'Bevaringsbiologi: Grønne landplanter',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5219/index.html'},
#   {'code': 'BIOS5311',
#    'name': 'Marine algers systematikk og økologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5311/index.html'},
#   {'code': 'BIOS5311F',
#    'name': 'Identification of Marine Microalgae and Macroalgae',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5311F/index.html'},
#   {'code': 'BIOS5312',
#    'name': 'Høyfjellsøkologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5312/index.html'},
#   {'code': 'BIOS5313',
#    'name': 'Menneskelig påvirkning på det marine miljø',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5313/index.html'},
#   {'code': 'BIOS5316',
#    'name': 'Giftige alger og algedyrking',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5316/index.html'},
#   {'code': 'BIOS5410',
#    'name': 'Regulatorisk toksikologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5410/index.html'},
#   {'code': 'BIOS5411',
#    'name': 'Miljøgifter i økosystem og mennesker: Effekter',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5411/index.html'},
#   {'code': 'BIOS5412',
#    'name': 'Miljøgifter i økosystem og mennesker: eksponering og akkumulering',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5412/index.html'},
#   {'code': 'BIOS5500',
#    'name': 'Vitenskapelig forfatterskap',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5500/index.html'},
#   {'code': 'BIOS5610',
#    'name': 'Eukaryote gener og genomer',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5610/index.html'},
#   {'code': 'BIOS5710',
#    'name': 'Advanced Cancer Biology',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5710/index.html'},
#   {'code': 'BIOS5810',
#    'name': 'Komparativ og økologisk fysiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5810/index.html'},
#   {'code': 'BIOS5812',
#    'name': 'Avansert fysiologi og nevrobiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5812/index.html'},
#   {'code': 'BIOS5910',
#    'name': 'Molecular biology of microbes - host interactions',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5910/index.html'},
#   {'code': 'BIOS5912',
#    'name': 'Eukaryote transkripsjonsfaktorer - strukturer, samspill, regulering',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5912/index.html'},
#   {'code': 'BIOS5913',
#    'name': 'Molekylære mekanismer i intracellulær transport',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5913/index.html'},
#   {'code': 'BIOS5914',
#    'name': 'Cellulær og molekylær immunologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5914/index.html'},
#   {'code': 'BIOS5930L',
#    'name': 'Masteroppgave i biovitenskap, Lektorprogrammet',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS5930L/index.html'},
#   {'code': 'BIOS9111',
#    'name': 'Elektronmikroskopi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9111/index.html'},
#   {'code': 'BIOS9112',
#    'name': 'Livshistoriestrategier og klimaeffekter',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9112/index.html'},
#   {'code': 'BIOS9113',
#    'name': 'Bevarings- og forvaltningsbiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9113/index.html'},
#   {'code': 'BIOS9114',
#    'name': 'Molekylær evolusjon',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9114/index.html'},
#   {'code': 'BIOS9140',
#    'name': 'Infection Biology of Microbial Symbiosis',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9140/index.html'},
#   {'code': 'BIOS9210',
#    'name': 'Gradientanalyseteknikker',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9210/index.html'},
#   {'code': 'BIOS9211',
#    'name': 'Utbredelsesmodellering',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9211/index.html'},
#   {'code': 'BIOS9213',
#    'name': 'Fylogeni og klassifikasjon',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9213/index.html'},
#   {'code': 'BIOS9214',
#    'name': 'Biogeografi og biodiversitet',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9214/index.html'},
#   {'code': 'BIOS9217',
#    'name': 'Evolusjon og systematikk i utvalgte grupper: soppriket',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9217/index.html'},
#   {'code': 'BIOS9219',
#    'name': 'Bevaringsbiologi: Grønne landplanter',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9219/index.html'},
#   {'code': 'BIOS9311',
#    'name': 'Marine algers systematikk og økologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9311/index.html'},
#   {'code': 'BIOS9312',
#    'name': 'Høyfjellsøkologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9312/index.html'},
#   {'code': 'BIOS9313',
#    'name': 'Menneskelig påvirkning på det marine miljø',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9313/index.html'},
#   {'code': 'BIOS9316',
#    'name': 'Giftige alger og algedyrking',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9316/index.html'},
#   {'code': 'BIOS9410',
#    'name': 'Regulatorisk toksikologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9410/index.html'},
#   {'code': 'BIOS9411',
#    'name': 'Miljøgifter i økosystem og mennesker: Effekter',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9411/index.html'},
#   {'code': 'BIOS9412',
#    'name': 'Miljøgifter i økosystem og mennesker: eksponering og akkumulering',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9412/index.html'},
#   {'code': 'BIOS9500',
#    'name': 'Vitenskapelig forfatterskap',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9500/index.html'},
#   {'code': 'BIOS9530',
#    'name': 'Biomolecular NMR',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9530/index.html'},
#   {'code': 'BIOS9610',
#    'name': 'Eukaryote gener og genomer',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9610/index.html'},
#   {'code': 'BIOS9710',
#    'name': 'Advanced Cancer Biology',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9710/index.html'},
#   {'code': 'BIOS9810',
#    'name': 'Komparativ og økologisk fysiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9810/index.html'},
#   {'code': 'BIOS9812',
#    'name': 'Avansert fysiologi og nevrobiologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9812/index.html'},
#   {'code': 'BIOS9905FBI2',
#    'name': 'Fylogenomikk',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9905FBI2/index.html'},
#   {'code': 'BIOS9910',
#    'name': 'Molecular and Cell Biology of Microbes - Host Interactions',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9910/index.html'},
#   {'code': 'BIOS9912',
#    'name': 'Eukaryote transkripsjonsfaktorer - strukturer, samspill, regulering',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9912/index.html'},
#   {'code': 'BIOS9913',
#    'name': 'Molekylære mekanismer i intracellulær transport',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9913/index.html'},
#   {'code': 'BIOS9914',
#    'name': 'Cellulær og molekylær immunologi',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9914/index.html'},
#   {'code': 'BIOS9980',
#    'name': 'Proteomics Basic Course',
#    'url': 'https://www.uio.no/studier/emner/matnat/ibv/BIOS9980/index.html'},
#   {'code': 'BKS1001',
#    'name': 'Bosnisk/kroatisk/serbisk språk 1',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS1001/index.html'},
#   {'code': 'BKS1002',
#    'name': 'Bosnisk/kroatisk/serbisk språk 2',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS1002/index.html'},
#   {'code': 'BKS1102',
#    'name': 'Bosnisk/kroatisk/serbisk språk 3',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS1102/index.html'},
#   {'code': 'BKS1110',
#    'name': 'Bosnisk/kroatisk/serbisk språk: Lyd, skrift og bøyningssystem',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS1110/index.html'},
#   {'code': 'BKS1120',
#    'name': 'Bosnisk/kroatisk/serbisk språk: Setninger og tekster',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS1120/index.html'},
#   {'code': 'BKS1121',
#    'name': 'Bosnisk/kroatisk/serbisk tekstlesning og praktisk språk',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS1121/index.html'},
#   {'code': 'BKS1301',
#    'name': 'Bosnisk/kroatisk/serbisk litteratur og samfunn',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS1301/index.html'},
#   {'code': 'BKS1501',
#    'name': 'Det tidligere Jugoslavia, historie, kultur, samfunn - innføring',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS1501/index.html'},
#   {'code': 'BKS2000',
#    'name': 'Bosnisk/kroatisk/serbisk tekstkultur',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS2000/index.html'},
#   {'code': 'BKS2020',
#    'name': 'Leseemne i bosnisk/kroatisk/serbisk',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS2020/index.html'},
#   {'code': 'BKS2103',
#    'name': 'Bosnisk/kroatisk/serbisk språk 4',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS2103/index.html'},
#   {'code': 'BKS2110',
#    'name': 'Bosnisk/kroatisk/serbisk språk: Historiske og teoretiske perspektiver',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS2110/index.html'},
#   {'code': 'BKS2111',
#    'name': 'Bosnisk/kroatisk/serbisk språk i bruk',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS2111/index.html'},
#   {'code': 'BKS2120',
#    'name': 'Bosnisk/kroatisk/serbisk grammatikk og oversettelse II',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS2120/index.html'},
#   {'code': 'BKS2124',
#    'name': 'Språk og nasjonalisme',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS2124/index.html'},
#   {'code': 'BKS2125',
#    'name': 'Bosnisk/kroatisk/serbisk språkhistorie',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS2125/index.html'},
#   {'code': 'BKS2300',
#    'name': 'Bosnisk/kroatisk/serbisk litteraturhistorie og litterær analyse',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS2300/index.html'},
#   {'code': 'BKS2301',
#    'name': 'Bosnisk/kroatisk/serbisk tekstlesning og litterær analyse',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS2301/index.html'},
#   {'code': 'BKS2302',
#    'name': 'Bosnisk/kroatisk/serbisk litteraturhistorie',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS2302/index.html'},
#   {'code': 'BKS2501',
#    'name': 'Det tidligere Jugoslavia, historie, kultur, samfunn - utdypning',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS2501/index.html'},
#   {'code': 'BKS4090',
#    'name': 'Masteroppgave i Bosnisk/kroatisk/serbisk ',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS4090/index.html'},
#   {'code': 'BKS4091',
#    'name': 'Masteroppgave i bosnisk/kroatisk/serbisk',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS4091/index.html'},
#   {'code': 'BKS4110',
#    'name': 'Bosnisk/kroatisk/serbisk diskursanalyse',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS4110/index.html'},
#   {'code': 'BKS4121',
#    'name': 'Bosnisk/kroatisk/serbisk tekststudium',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS4121/index.html'},
#   {'code': 'BKS4123',
#    'name': 'Oversettelse til og fra Bosnisk/kroatisk/serbisk',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS4123/index.html'},
#   {'code': 'BKS4490',
#    'name': 'Masteroppgave i oversettelse - bosnisk/kroatisk/serbisk',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS4490/index.html'},
#   {'code': 'BKS4500',
#    'name': 'BKS kulturkunnskap, metodisk innføring',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS4500/index.html'},
#   {'code': 'BKS4503',
#    'name': 'Kontroversielle temaer i bosnisk, kroatisk og serbisk historie',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS4503/index.html'},
#   {'code': 'BKS4590',
#    'name': 'Masteroppgave i Balkan-studier',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BKS4590/index.html'},
#   {'code': 'BUL2120',
#    'name': 'Bulgarsk syntaks og skriftlig språkbruk',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/BUL2120/index.html'},
#   {'code': 'CAENFRA1000',
#    'name': 'Fransk språkbruk 1',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/CAENFRA1000/index.html'},
#   {'code': 'CAENFRA1101',
#    'name': 'Fransk grammatikk 2 med didaktikk',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/CAENFRA1101/index.html'},
#   {'code': 'CAENFRA1102',
#    'name': 'Årskurs i fransk (i Caen) for lærere og lærerstudenter. Fonologi og fransk språkbruk 1',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/CAENFRA1102/index.html'},
#   {'code': 'CAENFRA1103',
#    'name': 'Årskurs i fransk (i Caen) for lærere og lærerstudenter. Fagdidaktikk. Fransk som fremmedspråk',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/CAENFRA1103/index.html'},
#   {'code': 'CAENFRA1104',
#    'name': 'Fransk språkbruk 2',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/CAENFRA1104/index.html'},
#   {'code': 'CAENFRA1110',
#    'name': 'Fransk grammatikk og fonetikk 1',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/CAENFRA1110/index.html'},
#   {'code': 'CAENFRA1301',
#    'name': 'Årskurs i fransk (i Caen) for lærere og lærerstudenter. Fransk litteratur',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/CAENFRA1301/index.html'},
#   {'code': 'CAENFRA1302',
#    'name': 'Litteratur og historie med didaktikk',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/CAENFRA1302/index.html'},
#   {'code': 'CAENFRA1501',
#    'name': 'Årskurs i fransk (i Caen) for lærere og lærerstudenter. Fransk kulturkunnskap og historie',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/CAENFRA1501/index.html'},
#   {'code': 'CAENFRA1502',
#    'name': 'Litteratur, geografi og kulturkunnskap',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/CAENFRA1502/index.html'},
#   {'code': 'CAR3900',
#    'name': 'Practice semster career: Asia',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/CAR3900/index.html'},
#   {'code': 'CONT4101',
#    'name': 'New Testament Contextual Theology, Jesus and the Kingdom of God',
#    'url': 'https://www.uio.no/studier/emner/teologi/tf/CONT4101/index.html'},
#   {'code': 'CONT4103',
#    'name': 'Paul - His Life and Theology',
#    'url': 'https://www.uio.no/studier/emner/teologi/tf/CONT4103/index.html'},
#   {'code': 'CONT4104',
#    'name': 'Childhood - Theological and Socio-Cultural Perspectives',
#    'url': 'https://www.uio.no/studier/emner/teologi/tf/CONT4104/index.html'},
#   {'code': 'CONT4105',
#    'name': 'Old Testament Theology',
#    'url': 'https://www.uio.no/studier/emner/teologi/tf/CONT4105/index.html'},
#   {'code': 'CONT4301',
#    'name': 'Church and Religion in Norwegian Society.',
#    'url': 'https://www.uio.no/studier/emner/teologi/tf/CONT4301/index.html'},
#   {'code': 'CONT4401',
#    'name': 'Religion: Source of Conflicts – Resource for Peace',
#    'url': 'https://www.uio.no/studier/emner/teologi/tf/CONT4401/index.html'},
#   {'code': 'CONT4402',
#    'name': 'Interreligious Relations',
#    'url': 'https://www.uio.no/studier/emner/teologi/tf/CONT4402/index.html'},
#   {'code': 'CONT4403',
#    'name': 'Jesus in Cultural Complexity',
#    'url': 'https://www.uio.no/studier/emner/teologi/tf/CONT4403/index-eng.html'},
#   {'code': 'CONT4404',
#    'name': 'Postcolonial readings of the New Testament',
#    'url': 'https://www.uio.no/studier/emner/teologi/tf/CONT4404/index.html'},
# ...
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4120/index.html'},
#   {'code': 'ENT4130',
#    'name': 'Entrepreneurship theory from a Singaporean point of view',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4130/index.html'},
#   {'code': 'ENT4140',
#    'name': 'Entrepreneurship theory from a South African point of view',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4140/index.html'},
#   {'code': 'ENT4190',
#    'name': 'Entrepreneurship Theory in an International Context',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4190/index.html'},
#   {'code': 'ENT4194',
#    'name': 'Consultancy Project',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4194/index.html'},
#   {'code': 'ENT4200',
#    'name': 'Startups in Practice - Entrepreneurship',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4200/index.html'},
#   {'code': 'ENT4210',
#    'name': 'Practical Innovation Management',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4210/index.html'},
#   {'code': 'ENT4220',
#    'name': 'Norwegian Practical Start-up Experience',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4220/index.html'},
#   {'code': 'ENT4300',
#    'name': 'Entrepreneurship and Internationalisation',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4300/index.html'},
#   {'code': 'ENT4310',
#    'name': 'Business economics and marketing',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4310/index.html'},
#   {'code': 'ENT4320',
#    'name': 'Marketing Management',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4320/index.html'},
#   {'code': 'ENT4340',
#    'name': 'Managing New Venture Growth',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4340/index.html'},
#   {'code': 'ENT4350',
#    'name': 'Entrepreneurial Sales and Marketing',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4350/index.html'},
#   {'code': 'ENT4360',
#    'name': 'Student Venture Creation Project',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4360/index.html'},
#   {'code': 'ENT4400',
#    'name': 'Corporate Innovation Strategies and Project Management',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4400/index.html'},
#   {'code': 'ENT4460',
#    'name': 'Corporate Entrepreneurship Project',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4460/index.html'},
#   {'code': 'ENT4500',
#    'name': 'Social Entrepreneurship',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4500/index.html'},
#   {'code': 'ENT4505',
#    'name': 'Social Entrepreneurship',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4505/index.html'},
#   {'code': 'ENT4510',
#    'name': 'Social Entrepreneurship in Practice',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT4510/index.html'},
#   {'code': 'ENT5100',
#    'name': 'Research Design',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT5100/index.html'},
#   {'code': 'ENT9600',
#    'name': 'Entrepreneurial teams and new business creation',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT9600/index.html'},
#   {'code': 'ENT9601',
#    'name': 'Entrepreneurship Research',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT9601/index.html'},
#   {'code': 'ENT9800',
#    'name': 'Innovation and Intellectual Property Rights',
#    'url': 'https://www.uio.no/studier/emner/matnat/sfe/ENT9800/index.html'},
#   {'code': 'ERN1000',
#    'name': 'Ernæringsstudiet, 1. semester',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN1000/index.html'},
#   {'code': 'ERN1010',
#    'name': 'Innføring i klinisk ernæring',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN1010/index.html'},
#   {'code': 'ERN1020',
#    'name': 'Ernæringsstudiet, 2. semester',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN1020/index.html'},
#   {'code': 'ERN1100',
#    'name': 'Ernæringsstudiet, Modul 1',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN1100/index.html'},
#   {'code': 'ERN2030',
#    'name': 'Ernæringsepidemiologi, kostholdsforskning og samfunnsernæring',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN2030/index.html'},
#   {'code': 'ERN2110',
#    'name': 'Kosthold, samfunn og ernæringsepidemiologi',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN2110/index.html'},
#   {'code': 'ERN2200',
#    'name': 'Ernæringsstudiet, modul 2',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN2200/index.html'},
#   {'code': 'ERN2200R',
#    'name': 'Fysiologi, ernæring og medisinsk biokjemi',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN2200R/index.html'},
#   {'code': 'ERN2300',
#    'name': 'Mikronæringsstoffer og fremmedstoffer – fra mekanismer til klinikk',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN2300/index.html'},
#   {'code': 'ERN3015',
#    'name': 'Ernæringsstudiet, 6. semester',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN3015/index.html'},
#   {'code': 'ERN3100',
#    'name': 'Kostholdsmetoder, metabolisme og klinisk ernæring',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN3100/index.html'},
#   {'code': 'ERN3110',
#    'name': 'Energigivende næringsstoffer og klinisk ernæring',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN3110/index.html'},
#   {'code': 'ERN3120',
#    'name': 'Molecular, cellular and clinical nutrition',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN3120/index.html'},
#   {'code': 'ERN3200',
#    'name': 'Forebyggende og klinisk ernæring',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN3200/index.html'},
#   {'code': 'ERN3300',
#    'name': 'Idrettsernæring',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN3300/index.html'},
#   {'code': 'ERN3400',
#    'name': 'Ernæring og media',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN3400/index.html'},
#   {'code': 'ERN4110',
#    'name': 'Statistikk for masterstudenter i ernæring',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4110/index.html'},
#   {'code': 'ERN4120',
#    'name': 'Humanforsøk',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4120/index.html'},
#   {'code': 'ERN4200',
#    'name': 'Ernæringsepidemiologi',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4200/index.html'},
#   {'code': 'ERN4210',
#    'name': 'Masteremne i ernæringsbiologi',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4210/index.html'},
#   {'code': 'ERN4221',
#    'name': 'Molecular Nutrition',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4221/index.html'},
#   {'code': 'ERN4230',
#    'name': 'Humanforsøk',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4230/index.html'},
#   {'code': 'ERN4250',
#    'name': 'Studieretningsemne i samfunnsernæring',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4250/index.html'},
#   {'code': 'ERN4260',
#    'name': 'Studieretningsemne i klinisk ernæring',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4260/index.html'},
#   {'code': 'ERN4300',
#    'name': 'Klinisk ernæringsforskning og kunnskapsoppsummering',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4300/index.html'},
#   {'code': 'ERN4310',
#    'name': 'Ernæringsepidemiologi og samfunnsernæring',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4310/index.html'},
#   {'code': 'ERN4321',
#    'name': 'The World Nutrition Situation - Data and Issues',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4321/index.html'},
#   {'code': 'ERN4322',
#    'name': 'Nutrition, Globalisation and Governance',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4322/index.html'},
#   {'code': 'ERN4323',
#    'name': 'Nutrition and Human Rights',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4323/index.html'},
#   {'code': 'ERN4340',
#    'name': 'Molekylærbiologisk ernæring',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4340/index.html'},
#   {'code': 'ERN4360',
#    'name': 'Masteremne i klinisk ernæring',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4360/index.html'},
#   {'code': 'ERN4400',
#    'name': 'Avansert klinisk ernæring',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4400/index.html'},
#   {'code': 'ERN4410',
#    'name': 'Masteremne i klinisk ernæring',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4410/index.html'},
#   {'code': 'ERN4500',
#    'name': 'Klinisk praksis',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4500/index.html'},
#   {'code': 'ERN4900',
#    'name': 'Masteroppgave i ernæring',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN4900/index.html'},
#   {'code': 'ERN5440',
#    'name': 'Glycobiology',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERN5440/index.html'},
#   {'code': 'ERNSEM1',
#    'name': 'Ernæringsstudiet, 1. semester',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERNSEM1/index.html'},
#   {'code': 'ERNSEM2',
#    'name': 'Ernæringsstudiet, 2. semester',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERNSEM2/index.html'},
#   {'code': 'ERNSEM3',
#    'name': 'Ernæringsstudiet, 3. semester',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERNSEM3/index.html'},
#   {'code': 'ERNSEM4A',
#    'name': 'Ernæringsstudiet, 4. semester',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERNSEM4A/index.html'},
#   {'code': 'ERNSEM4B',
#    'name': 'Ernæringsstudiet, 4. semester, andre del',
#    'url': 'https://www.uio.no/studier/emner/medisin/nutri/ERNSEM4B/index.html'},
#   {'code': 'EST1000',
#    'name': 'Introduksjon til estetikk',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EST1000/index.html'},
#   {'code': 'EST2000',
#    'name': 'Moderne estetisk teori',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EST2000/index.html'},
#   {'code': 'EST3010',
#    'name': 'Tverrestetisk prosjektarbeid',
#    'url': 'https://www.uio.no/studier/emner/hf/imk/EST3010/index.html'},
#   {'code': 'EST4000',
#    'name': 'Estetiske teorier',
#    'url': 'https://www.uio.no/studier/emner/hf/imv/EST4000/index.html'},
#   {'code': 'EST4001',
#    'name': 'Oppgaveseminar 1: Metode og prosjektbeskrivelse',
#    'url': 'https://www.uio.no/studier/emner/hf/imk/EST4001/index.html'},
#   {'code': 'EST4002',
#    'name': 'Estetikk. Oppgaveseminar 2: Skriveseminar',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EST4002/index.html'},
#   {'code': 'EST4003',
#    'name': 'Oppgaveseminar 1: Metode og prosjektbeskrivelse',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EST4003/index.html'},
#   {'code': 'EST4004',
#    'name': 'Skriveseminar for estetikkprogrammet',
#    'url': 'https://www.uio.no/studier/emner/hf/imk/EST4004/index.html'},
#   {'code': 'EST4010',
#    'name': 'Moderne estetisk teori',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EST4010/index.html'},
#   {'code': 'EST4390',
#    'name': 'Tverrestetisk masteroppgave – allmenn litteraturvitenskap',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EST4390/index.html'},
#   {'code': 'EST4391',
#    'name': 'Tverrestetisk masteroppgave - Engelskspråklig litteratur',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EST4391/index.html'},
#   {'code': 'EST4394',
#    'name': 'Tverrestetisk masteroppgave – nordisk litteraturvitenskap',
#    'url': 'https://www.uio.no/studier/emner/hf/iln/EST4394/index.html'},
#   {'code': 'EST4397',
#    'name': 'Tverrestetisk masteroppgave - tyskspråklig litteratur',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EST4397/index.html'},
#   {'code': 'EST4591',
#    'name': 'Tverrestetisk masteroppgave - kunsthistorie',
#    'url': 'https://www.uio.no/studier/emner/hf/ifikk/EST4591/index.html'},
#   {'code': 'EST4592',
#    'name': 'Tverrestetisk masteroppgave-medievitenskap',
#    'url': 'https://www.uio.no/studier/emner/hf/imk/EST4592/index.html'},
#   {'code': 'EST4593',
#    'name': 'Tverrestetisk masteroppgave i musikkvitenskap',
#    'url': 'https://www.uio.no/studier/emner/hf/imv/EST4593/index.html'},
#   {'code': 'EST4594',
#    'name': 'Tverrestetisk masteroppgave - teatervitenskap',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/EST4594/index.html'},
#   {'code': 'ETNO1010',
#    'name': 'Byggeskikk og boligforhold',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ETNO1010/index.html'},
#   {'code': 'ETNO1020',
#    'name': 'Kulturlandskap',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ETNO1020/index.html'},
#   {'code': 'ETNO1030',
#    'name': 'Individ og kollektiv',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ETNO1030/index.html'},
#   {'code': 'ETNO1040',
#    'name': 'Primærnæringenes kulturhistorie: Jordbruk',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ETNO1040/index.html'},
#   {'code': 'ETNO2010',
#    'name': 'Kulturminnevernets historie',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ETNO2010/index.html'},
#   {'code': 'ETNO2020',
#    'name': 'Materiell kultur',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ETNO2020/index.html'},
#   {'code': 'ETNO2030',
#    'name': 'Natur og kultur: Forholdet mellom mennesker og dyr',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ETNO2030/index.html'},
#   {'code': 'ETNO2040',
#    'name': 'Mat: Kultur og historie',
#    'url': 'https://www.uio.no/studier/emner/hf/ikos/ETNO2040/index.html'},
#   {'code': 'EURO1000',
#    'name': 'Europa og EU: historisk innføring',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EURO1000/index.html'},
#   {'code': 'EURO2100',
#    'name': 'EØS-regelverket; innhold og betydning for nasjonal handlefrihet',
#    'url': 'https://www.uio.no/studier/emner/sv/sv/EURO2100/index.html'},
#   {'code': 'EURO2101',
#    'name': 'EØS-regelverket; innhold og betydning for nasjonal handlefrihet',
#    'url': 'https://www.uio.no/studier/emner/jus/jus/EURO2101/index.html'},
#   {'code': 'EURO3090',
#    'name': 'Oppgaveemne i Europastudier (EU)',
#    'url': 'https://www.uio.no/studier/emner/sv/sv/EURO3090/index.html'},
#   {'code': 'EUS3000',
#    'name': 'Prosjektemne for bachelorprogrammet Europeiske språk',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EUS3000/index.html'},
#   {'code': 'EUS3905',
#    'name': 'Arbeidspraksis: Europeiske språk, estetiske studier og allmenn litteraturvitenskap',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EUS3905/index.html'},
#   {'code': 'EUS3910A',
#    'name': 'Arbeidspraksis: Europeiske språk, estetiske studier og allmenn litteraturvitenskap',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EUS3910/index.html'},
#   {'code': 'EUS3910B',
#    'name': 'Arbeidspraksis: Europeiske språk, estetiske studier og allmenn litteraturvitenskap',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EUS3910B/index.html'},
#   {'code': 'EUS3920',
#    'name': 'Arbeidspraksis: Europeiske språk, estetiske studier og allmenn litteraturvitenskap',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EUS3920/index.html'},
#   {'code': 'EUS3930',
#    'name': 'Arbeidspraksis: Europeiske språk, estetiske studier og allmenn litteraturvitenskap',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EUS3930/index.html'},
#   {'code': 'EUS4010',
#    'name': 'Borders, bodies and memories: Textual and cultural representation of contemporary migration in Europe',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EUS4010/index.html'},
#   {'code': 'EUS4011',
#    'name': 'Digital Humanities: How to Read a Million Books?',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EUS4011/index.html'},
#   {'code': 'EUS4015',
#    'name': 'Læringsressurser i fremmedspråk',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EUS4015/index.html'},
#   {'code': 'EUS4310',
#    'name': 'Cognitive Poetics',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EUS4310/index.html'},
#   {'code': 'EUS4900',
#    'name': 'Internasjonalt prosjektsemester europeiske språk',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EUS4900/index.html'},
#   {'code': 'EUS4905',
#    'name': 'Praksisemne for masterprogrammet Europeiske språk',
#    'url': 'https://www.uio.no/studier/emner/hf/ilos/EUS4905/index.html'},
#   ...],
#  'metadata': {'count': 8777,
#   'limit': 0,
#   'offset': 0,
#   'status': 'OK',
#   'total': 8777}}

# %%
df = pd.DataFrame(data['courses'], columns = ['code', 'name', 'url'])
df
# Out:
#              code                                            name  \
# 0            4360                 Macroeconomic policy and models
# 1            4410             Introductory dynamic macroeconomics
# 2            4940                        Economic Reform in China
# 3            5210                        Topics in microeconomics
# 4            5315                  Recursive Macroeconomic Theory
# ...           ...                                             ...
# 8772  VMSIAKH4190  Master's thesis in Viking and Medieval Studies
# 8773  VMSIAKH4195  Master's thesis in Viking and Medieval Studies
# 8774      ØAS1502                           Øst-Asias idéhistorie
# 8775      ØAS4510                             Østasiatisk seminar
# 8776      ØAS4590                         Masteroppgave: Øst asia
#
#                                                     url
# 0     https://www.uio.no/studier/emner/sv/oekonomi/E...
# 1     https://www.uio.no/studier/emner/sv/oekonomi/E...
# 2     https://www.uio.no/studier/emner/sv/oekonomi/E...
# 3     https://www.uio.no/studier/emner/sv/oekonomi/E...
# 4     https://www.uio.no/studier/emner/sv/oekonomi/E...
# ...                                                 ...
# 8772  https://www.uio.no/studier/emner/hf/iakh/VMSIA...
# 8773  https://www.uio.no/studier/emner/hf/iakh/VMSIA...
# 8774  https://www.uio.no/studier/emner/hf/ikos/OAS15...
# 8775  https://www.uio.no/studier/emner/hf/ikos/OAS45...
# 8776  https://www.uio.no/studier/emner/hf/ikos/OAS45...
#
# [8777 rows x 3 columns]

# %%
# second topic

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://opentdb.com/api.php?amount=10"

# %%
response = requests.get(url)

# %%
res = response.json()['results']

pd.json_normalize(res)
# Out:
#                      category      type difficulty  \
# 0           General Knowledge  multiple       easy
# 1           General Knowledge   boolean       easy
# 2                   Geography   boolean       easy
# 3   Entertainment: Television  multiple       hard
# 4           General Knowledge  multiple       easy
# 5         Entertainment: Film  multiple       easy
# 6           General Knowledge  multiple     medium
# 7           General Knowledge   boolean     medium
# 8                     History   boolean       hard
# 9  Entertainment: Video Games   boolean     medium
#
#                                             question        correct_answer  \
# 0              How would one say goodbye in Spanish?          Adi&oacute;s
# 1  It is automatically considered entrapment in t...                 False
# 2                    There are no deserts in Europe.                  True
# 3  In &quot;It&#039;s Always Sunny in Philadelphi...         The Trash Man
# 4  Which one of these is not a typical European s...              Scimitar
# 5  In the 2012 film, &quot;The Lorax&quot;, who i...  Aloysius O&#039;Hare
# 6  What is the Portuguese word for &quot;Brazil&q...                Brasil
# 7  The scientific name for the Southern Lights is...                  True
# 8  The man that shot Alexander Hamilton was named...                  True
# 9  In &quot;Resident Evil&quot;, only Chris has a...                 False
#
#                            incorrect_answers
# 0                  [ Hola, Au Revoir, Salir]
# 1                                     [True]
# 2                                    [False]
# 3         [Bird of War, Day Man, The Maniac]
# 4            [Falchion, Ulfberht, Flamberge]
# 5  [Ted Wiggins, The Once-Ler, Grammy Norma]
# 6          [Brazil, Brasilia, Bras&iacute;l]
# 7                                    [False]
# 8                                    [False]
# 9                                     [True]

# %%
# third topic 
import json
import os
import string
import sys


def _country_filter(src, scope, out):
    """
    Search the data for a single country
    :arg src: source dictionary
    :arg scope: source selector
    """

# %%
def filter(entry, item):
    matching = entry["country"]
    if item == matching or item == matching.lower() or item == matching.upper():
        return True
    else:
        return False
    return [entry for entry in src if filter(entry, scope)]

# %%
def country_filter(src, scopes):
    """
    Either make multiple data searches or
    execute one. {NEEDS IMPROVEMENT, O(kN) => O(n)}
    :arg src: source dictionary
    :arg scopes: source selectors
    """
    out = []

    if type(scopes) is list:
        [out.extend(_country_filter(src, scope, out)) for scope in scopes]
    else:
        out = _country_filter(src, scopes, out)

    return out

# %%
def main():
    args = []
    temp_arg = ""
    first_word = True

    # Retrieve our selecting countries (seperated by commas)
    for arg in sys.argv[1:]:
        temp_arg += arg if first_word else " " + arg
        first_word = False

        if arg[-1] == ",":
            args.append(temp_arg[:-1])
            temp_arg = ""
            first_word = True

    if temp_arg:
        args.append(temp_arg)

    if not args:
        return

    # Load the source
    src = None
    with open("world_universities_and_domains.json") as src_file:
        src = json.load(src_file)

    if src is None:
        return

    # Write the filtered result
    with open("filtered_world_universities_and_domains.json", "w") as dest_file:
        json.dump(country_filter(src, args), dest_file)


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14420\3049668348.py in <module>
#      34
#      35 if __name__ == "__main__":
# ---> 36     main()
#
# ~\AppData\Local\Temp\ipykernel_14420\3049668348.py in main()
#      23     src = None
#      24     with open("world_universities_and_domains.json") as src_file:
# ---> 25         src = json.load(src_file)
#      26
#      27     if src is None:
#
# ~\anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# ~\anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 326496: character maps to <undefined>

# %%
# fourth topic

# %%
#all the authors with name Rowling
books = requests.get('https://openlibrary.org/search/authors.json?q=j%20k%20rowling').json()
books
# Out:
# {'numFound': 6,
#  'start': 0,
#  'numFoundExact': True,
#  'docs': [{'key': 'OL23919A',
#    'type': 'author',
#    'name': 'J. K. Rowling',
#    'alternate_names': ['Joanne Rowling',
#     'Joanne K. Rowling',
#     'Jo Murray',
#     'Kennilworthy Whisp',
#     'JK Rowling',
#     'Robert Galbraith',
#     'Джоан Роулінг',
#     'Dzhoan Rouling',
#     'J.K. Rowling',
#     'ROWLING',
#     'روبرت غالبريث - Robert Galbraith',
#     'Rouling Dzh.K.',
#     'Newt Scamander',
#     'Newton Scamander'],
#    'birth_date': '31 July 1965',
#    'top_work': "Harry Potter and the Philosopher's Stone",
#    'work_count': 321,
#    'top_subjects': ['Fiction',
#     "Children's fiction",
#     'Fantasy fiction',
#     'New York Times bestseller',
#     'Harry Potter',
#     'Wizards, fiction',
#     'Magic',
#     'England, fiction',
#     'Wizards',
#     'Juvenile fiction'],
#    '_version_': 1751040922435452949},
#   {'key': 'OL11473870A',
#    'type': 'author',
#    'name': 'J K Rowling',
#    'top_work': 'Harry Potter and the Half-Blood Prince [2/2]',
#    'work_count': 1,
#    '_version_': 1751616823602708480},
#   {'key': 'OL11295942A',
#    'type': 'author',
#    'name': 'J. K. Rowling',
#    'work_count': 0,
#    '_version_': 1751073512749006854},
#   {'key': 'OL10829675A',
#    'type': 'author',
#    'name': 'J K Rowling; Yuko Matsuoka',
#    'work_count': 0,
#    '_version_': 1749259485304586240},
#   {'key': 'OL10650745A',
#    'type': 'author',
#    'name': 'Lia Wyler (Tradutor) J. K. Rowling ',
#    'work_count': 0,
#    '_version_': 1743399222225403904},
#   {'key': 'OL11515520A',
#    'type': 'author',
#    'name': 'J. K Rowling (creator) Jack Thorne',
#    'work_count': 0,
#    '_version_': 1751638111948898304}]}

# %%
books['docs']
data = pd.DataFrame.from_dict(books['docs']).reset_index()
data
# Out:
#    index          key    type                                 name  \
# 0      0     OL23919A  author                        J. K. Rowling
# 1      1  OL11473870A  author                          J K Rowling
# 2      2  OL11295942A  author                        J. K. Rowling
# 3      3  OL10829675A  author           J K Rowling; Yuko Matsuoka
# 4      4  OL10650745A  author  Lia Wyler (Tradutor) J. K. Rowling
# 5      5  OL11515520A  author   J. K Rowling (creator) Jack Thorne
#
#                                      alternate_names    birth_date  \
# 0  [Joanne Rowling, Joanne K. Rowling, Jo Murray,...  31 July 1965
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
# 5                                                NaN           NaN
#
#                                        top_work  work_count  \
# 0      Harry Potter and the Philosopher's Stone         321
# 1  Harry Potter and the Half-Blood Prince [2/2]           1
# 2                                           NaN           0
# 3                                           NaN           0
# 4                                           NaN           0
# 5                                           NaN           0
#
#                                         top_subjects            _version_
# 0  [Fiction, Children's fiction, Fantasy fiction,...  1751040922435452949
# 1                                                NaN  1751616823602708480
# 2                                                NaN  1751073512749006854
# 3                                                NaN  1749259485304586240
# 4                                                NaN  1743399222225403904
# 5                                                NaN  1751638111948898304
